# %%
import pandas as pd

data = {"Id_producto": [1001, 1002, 1003, 1003],
        "Cantidad_vendida": [30, None, 25, 25],
        "Precio": [20.5, 15.0, None, 22.5]}

df = pd.DataFrame(data)
df
# Out:
#    Id_producto  Cantidad_vendida  Precio
# 0         1001              30.0    20.5
# 1         1002               NaN    15.0
# 2         1003              25.0     NaN
# 3         1003              25.0    22.5

# %%
df.head()
# Out:
#    Id_producto  Cantidad_vendida  Precio
# 0         1001              30.0    20.5
# 1         1002               NaN    15.0
# 2         1003              25.0     NaN
# 3         1003              25.0    22.5

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id_producto       4 non-null      int64
#  1   Cantidad_vendida  3 non-null      float64
#  2   Precio            3 non-null      float64
# dtypes: float64(2), int64(1)
# memory usage: 228.0 bytes

# %%
df.isnull()
# Out:
#    Id_producto  Cantidad_vendida  Precio
# 0        False             False   False
# 1        False              True   False
# 2        False             False    True
# 3        False             False   False

# %%
df.isnull().sum()
# Out:
# Id_producto         0
# Cantidad_vendida    1
# Precio              1
# dtype: int64

# %%
df_eliminados = df.dropna()
df_eliminados
# Out:
#    Id_producto  Cantidad_vendida  Precio
# 0         1001              30.0    20.5
# 3         1003              25.0    22.5

# %%
valores_nuevos = {'Cantidad_vendida': 0, 'Precio': df['Precio'].mean()}
df_rellenados = df.fillna(valores_nuevos)
df_rellenados
# Out:
#    Id_producto  Cantidad_vendida     Precio
# 0         1001              30.0  20.500000
# 1         1002               0.0  15.000000
# 2         1003              25.0  19.333333
# 3         1003              25.0  22.500000

# %%
df_rellenados['Cantidad_vendida'] = df_rellenados['Cantidad_vendida'].astype(int)

df_rellenados
# Out:
#    Id_producto  Cantidad_vendida     Precio
# 0         1001                30  20.500000
# 1         1002                 0  15.000000
# 2         1003                25  19.333333
# 3         1003                25  22.500000

# %%
#Si no pones algo en el parentesis del drop_duplicates() sólo borra registros que seean exactanmente iguales en todas las columnas
df_unicos = df_rellenados.drop_duplicates()
df_unicos
# Out:
#    Id_producto  Cantidad_vendida     Precio
# 0         1001                30  20.500000
# 1         1002                 0  15.000000
# 2         1003                25  19.333333
# 3         1003                25  22.500000

# %%
df_unicos = df_rellenados.drop_duplicates(subset='Id_producto')
df_unicos
# Out:
#    Id_producto  Cantidad_vendida     Precio
# 0         1001                30  20.500000
# 1         1002                 0  15.000000
# 2         1003                25  19.333333
